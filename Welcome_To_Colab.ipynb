# %% [markdown]
# <a href="https://colab.research.google.com/github/IYORIYAGAMI/OPEN-SOURCE/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("heights_with_outliers.csv")
df.head()
# Out:
#        name  height
# 0     Aarav    5.45
# 1   Deepika    8.20
# 2  Abhishek    5.65
# 3     Sneha    5.52
# 4     Kriti    5.69

# %%
df.describe()
# Out:
#             height
# count  1000.000000
# mean      5.611180
# std       0.372654
# min       3.200000
# 25%       5.350000
# 50%       5.625000
# 75%       5.852500
# max       9.400000

# %%
mean=df.height.mean()
std=df.height.std()
mean,std
# Out:
# (np.float64(5.61118), 0.3726535633511086)

# %%
sns.histplot(df.height, kde=True)

plt.axvline(mean, color='k', linestyle='dashed', linewidth=1)

# one stadard deviation
plt.axvline(mean + std, color='r', linestyle='dashed', linewidth=1)
plt.axvline(mean - std, color='r', linestyle='dashed', linewidth=1)

# two standard deviation
plt.axvline(mean + 2*std, color='g', linestyle='dashed', linewidth=1)
plt.axvline(mean - 2*std, color='g', linestyle='dashed', linewidth=1)

# three standard deviation
plt.axvline(mean + 3*std, color='b', linestyle='dashed', linewidth=1)
plt.axvline(mean - 3*std, color='b', linestyle='dashed', linewidth=1)

# %%
lower=df.height.mean()- 3*df.height.std()
upper=df.height.mean()+ 3*df.height.std()
lower,upper
# Out:
# (np.float64(4.493219309946674), np.float64(6.729140690053326))

# %%
df[(df.height<lower)|(df.height>upper)]
# Out:
#        name  height
# 1   Deepika     8.2
# 16    Tanvi     3.2
# 57    Priya     3.4
# 76    Aarav     9.4

# %%
df_no_outliers=df[(df.height>lower)&(df.height<upper)]
df_no_outliers
# Out:
#          name  height
# 0       Aarav    5.45
# 2    Abhishek    5.65
# 3       Sneha    5.52
# 4       Kriti    5.69
# 5       Sneha    5.24
# ..        ...     ...
# 995     Susan    5.51
# 996     Sarah    5.85
# 997     Susan    6.12
# 998   Michael    5.81
# 999     David    5.41
#
# [996 rows x 2 columns]

# %%
df_no_outliers.to_excel("filtered.xlsx")

# %%
sns.histplot(df_no_outliers.height)
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
df=pd.read_csv("bill_survey.csv")
df.head()
# Out:
#      City   Bill
# 0  Mumbai  15400
# 1  Mumbai   6700
# 2  Mumbai  16300
# 3  Mumbai   2100
# 4  Mumbai   4600

# %%
df.shape
# Out:
# (10350, 2)

# %%
df.City.nunique()
# Out:
# 207

# %%
sns.histplot(df.Bill,kde=True)
# Out:
# <Axes: xlabel='Bill', ylabel='Count'>

# %%
sns.histplot(df[df.City=="Mumbai"].Bill,kde=True)
# Out:
# <Axes: xlabel='Bill', ylabel='Count'>

# %%
sns.histplot(df[df.City=="Kolkata"].Bill,kde=True)
# Out:
# <Axes: xlabel='Bill', ylabel='Count'>

# %%
sns.histplot(df[df.City=="Delhi"].Bill,kde=True)
# Out:
# <Axes: xlabel='Bill', ylabel='Count'>

# %%
sns.histplot(df[df.City=="Agra"].Bill,kde=True)
# Out:
# <Axes: xlabel='Bill', ylabel='Count'>

# %%
g=df.groupby("City")

for city,subdf in g:
  print(city)
  print(subdf)
  break
# Out:
# Agartala
#           City   Bill
# 5500  Agartala   4500
# 5501  Agartala   8800
# 5502  Agartala   8000
# 5503  Agartala   8700
# 5504  Agartala  13400
# 5505  Agartala   6500
# 5506  Agartala   3400
356.0), np.float64(6262.0), np.float64(5472.0), np.float64(6820.0), np.float64(4928.0), np.float64(6378.0), np.float64(6450.0), np.float64(5620.0), np.float64(6114.0), np.float64(6176.0), np.float64(4582.0), np.float64(6992.0), np.float64(5990.0), np.float64(5602.0), np.float64(6356.0), np.float64(5856.0), np.float64(8176.0), np.float64(5484.0), np.float64(5688.0), np.float64(4854.0), np.float64(6042.0), np.float64(5638.0), np.float64(6066.0), np.float64(5880.0), np.float64(5774.0), np.float64(6958.0), np.float64(5908.0), np.float64(7652.0), np.float64(5134.0), np.float64(5372.0), np.float64(5146.0), np.float64(5086.0), np.float64(6310.0), ...
# [np.float64(6276.0),
#  np.float64(6084.0),
#  np.float64(5990.0),
#  np.float64(5588.0),
#  np.float64(5680.0)]

# %%
sns.histplot(sample_means,kde=True)
plt.xlabel("Electrcity bill sample means")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df=pd.read_csv("/content/miles.csv")
df.head()
# Out:
#          date  is_weekend  miles
# 0  2022-01-01       False     27
# 1  2022-01-02        True      5
# 2  2022-01-03       False     36
# 3  2022-01-04       False     32
# 4  2022-01-05       False     23

# %%
df.shape
# Out:
# (730, 3)

# %%
plt.figure(figsize=(12,5))
plt.plot(df.miles)

# %%
sns.histplot(df.miles,kde=True)
# Out:
# <Axes: xlabel='miles', ylabel='Count'>

# %%
df.miles.describe()
# Out:
# count    730.000000
# mean      27.627397
# std       15.437588
# min        0.000000
# 25%       21.000000
# 50%       28.000000
# 75%       35.000000
# max      148.000000
# Name: miles, dtype: float64

# %%
mean_population=df.miles.mean()
std_population=df.miles.std()
mean_population,std_population
# Out:
# (np.float64(27.627397260273973), 15.437588497596295)

# %%
sample_size=50
sample=df.sample(sample_size,random_state=100)
sample.head()
# Out:
#            date  is_weekend  miles
# 184  2022-07-04       False     24
# 535  2023-06-20       False     36
# 299  2022-10-27       False     41
# 221  2022-08-10       False     20
# 152  2022-06-02       False     38

# %%
mean_sample=sample.miles.mean()
std_dev_sample=sample.miles.std()
mean_sample,std_dev_sample
# Out:
# (np.float64(25.82), 8.805587280070466)

# %%
import scipy.stats as st

z_score_95=st.norm.ppf(0.975)
z_score_95
# Out:
# np.float64(1.959963984540054)

# %%
import numpy as np

# %%
margin_of_error=z_score_95*(std_population/np.sqrt(sample_size))
margin_of_error
# Out:
# np.float64(4.2790025875110596)

# %%
lower=mean_sample-margin_of_error
upper=mean_sample+margin_of_error
lower,upper
# Out:
# (np.float64(21.54099741248894), np.float64(30.09900258751106))

# %%
df=pd.read_csv("/content/house_price_increase.csv")
df.head()
# Out:
#   house_id  price_increase_pct
# 0    NJ001                12.7
# 1    NJ002                11.3
# 2    NJ003                11.9
# 3    NJ004                13.2
# 4    NJ005                12.8

# %%
df.shape
# Out:
# (100, 2)

# %%
population_mean=10
population_std=4

# %%
sample_mean=df.price_increase_pct.mean()
sample_mean
# Out:
# np.float64(11.0)

# %%
sample_size=df.shape[0]
sample_size
# Out:
# 100

# %%
standard_error=population_std/np.sqrt(sample_size)
standard_error
# Out:
# np.float64(0.4)

# %%
z_score=(sample_mean-population_mean)/standard_error
z_score
# Out:
# np.float64(2.5)

# %%
alpha = 0.01

# %%
from scipy import stats

# %%
z_critical=stats.norm.ppf(1-alpha)
z_critical
# Out:
# np.float64(2.3263478740408408)
